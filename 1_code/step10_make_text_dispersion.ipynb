# %% [markdown]
# # Solution for computing market level entropy

# %% [markdown]
# ## Part 1 - making the ''inventory'' of reviews (per market, month)
# ### inputs:
# - es_market_id ( month- market-installerid)
# - reviews ( installerid-reviewid-timestamp)
# ### process
# - combine es_market_id and reviews, we can find out for each market, each month, the *set* of reviews that are present on the market and record the list of review ids
# ### output :
# - inventory file
# - obs is on installer-mkt-month level.
# - every obs
#     - identifiers(installer id, market, year_month_count)
#     - list of their own reviews id at that time
#     - list of the other reviews id at that time
#     - list of all reviews ids ( own and others)

# %%
pwd
# Out:
# 'C:\\Users\\Herbie Huang\\Google Drive\\Current_SolarResearch\\working_june2020\\solar_project\\1_code'

# %% [markdown]
# ## Input: market levels from step 3

# %%
import pandas as pd 
temp_es_market=pd.read_csv('../2_pipeline/es_marketlevel90_100_2two_step.csv')

# %%
temp_es_market['year_month_count'].describe()
# Out:
# count    8113.000000
# mean       43.258228
# std        14.543701
# min         1.000000
# 25%        34.000000
# 50%        46.000000
# 75%        55.000000
# max        64.000000
# Name: year_month_count, dtype: float64

# %%
es_market_ids=temp_es_market[['installer_id','market','year_month_count']].drop_duplicates()

# %%
es_market_ids.describe()
# Out:
#        installer_id       market  year_month_count
# count   8113.000000  8113.000000       8113.000000
# mean   17971.731912    17.784667         43.258228
# std     6707.006717    13.486967         14.543701
# min      108.000000    -1.000000          1.000000
# 25%    20131.000000     4.000000         34.000000
# 50%    20627.000000    17.000000         46.000000
# 75%    21350.000000    33.000000         55.000000
# max    23027.000000    36.000000         64.000000

# %% [markdown]
# import pandas as pd
# es_market_ids=pd.read_csv('es_market_ids.csv')

# %% [markdown]
# ## input: raw reviews data : installer_review_data_20180410.csv

# %%
reviews=pd.read_csv('../0_data/Lock_ES_RawData/installer_review_data_20180410.csv',sep=',',escapechar='\\')

# %%
reviews=reviews[['id','installer_id','date_created']]
reviews['date_created']=pd.to_datetime(reviews['date_created'])
reviews['year']=reviews['date_created'].apply(lambda x:x.year)
reviews['month']=reviews['date_created'].apply(lambda x:x.month)
reviews['year_month_count']=12*(reviews['year']-2013)+reviews['month']

# %%
es_market_ids.head()
# Out:
#    installer_id  market  year_month_count
# 0         21283     0.0              35.0
# 1         21283     0.0              36.0
# 2         21283     0.0              37.0
# 3         21283     0.0              38.0
# 4         21283     0.0              39.0

# %%
es_market_ids[es_market_ids['installer_id']==20292]
# Out:
# Empty DataFrame
# Columns: [installer_id, market, year_month_count]
# Index: []

# %%
es_market_ids_no_time=es_market_ids[['installer_id','market']].drop_duplicates()

# %% [markdown]
# We need to assign review ids to markets. Right now they are assigned to installers.

# %%
es_market_ids_no_time.describe()
# Out:
#        installer_id      market
# count    385.000000  385.000000
# mean   19452.335065   16.976623
# std     5830.528403   13.278938
# min      108.000000   -1.000000
# 25%    20552.000000    4.000000
# 50%    21347.000000   17.000000
# 75%    21838.000000   31.000000
# max    23027.000000   36.000000

# %%
reviews=pd.merge(left=reviews,right=es_market_ids_no_time,on=['installer_id'],how='left').dropna()

# %%
reviews.head()
# Out:
#    id  installer_id        date_created  year  month  year_month_count  market
# 1   2           556 2013-02-18 20:03:23  2013      2                 2    36.0
# 2   3           857 2013-03-19 00:51:14  2013      3                 3    34.0
# 4   5           857 2013-04-26 22:52:20  2013      4                 4    34.0
# 5   6         20193 2013-06-07 15:33:22  2013      6                 6    20.0
# 8   9          6507 2013-07-04 01:36:06  2013      7                 7    36.0

# %% [markdown]
# Loop:
# - loop over market, slice the es_market_ids
# - for the slice, loop over month,
#     - in month K, find all reviews that belonged on the market -> list_reviews_mkt
#     - in same month k, find all reviews that belonged to self -> list_reviews_self

# %%
results_collection=[]
for market in set(es_market_ids.market):
    print('market:'+str(market))
    temp1=es_market_ids[es_market_ids['market']==market]
    for m in set(temp1.year_month_count):
        print('month: '+str(m))
        temp2=temp1[temp1['year_month_count']<=m]
        installers=set(temp2.installer_id)
        #print(installers)
        if installers:
            for i in installers:
                list_reviews_mkt=reviews[(reviews['market']==market)&(reviews['year_month_count']<=m)].id
                list_reviews_self=reviews[(reviews['market']==market)&(reviews['year_month_count']<=m)&(reviews['installer_id']==i)].id
                list_reviews_others=reviews[(reviews['market']==market)&(reviews['year_month_count']<=m)&(reviews['installer_id']!=i)].id
                temp_to_collect=[market,m,i,list_reviews_mkt,list_reviews_self,list_reviews_others]
                results_collection.append(temp_to_collect)
# Out:
# market:0.0
# month: 35.0
# month: 36.0
# month: 37.0
# month: 38.0
# month: 39.0
# month: 40.0
# month: 41.0
# month: 42.0
# month: 43.0
# month: 44.0
# month: 45.0
# month: 46.0
# month: 47.0
# month: 48.0
# month: 49.0
# month: 50.0
# month: 51.0
# month: 52.0
# month: 53.0
# month: 54.0
# month: 55.0
# month: 56.0
# month: 57.0
# month: 58.0
# month: 59.0
# month: 60.0
# month: 61.0
# month: 62.0
# month: 63.0
# month: 64.0
# market:1.0
# month: 7.0
# month: 8.0
# month: 9.0
# month: 10.0
# month: 11.0
# month: 12.0
# month: 13.0
# month: 14.0
# month: 15.0
# month: 16.0
# month: 17.0
# month: 18.0
# month: 19.0
# month: 20.0
# month: 21.0
# month: 22.0
# month: 23.0
# month: 24.0
# month: 25.0
# month: 26.0
# month: 27.0
# month: 28.0
# month: 29.0
# month: 30.0
# month: 31.0
# month: 32.0
# month: 33.0
# month: 34.0
# month: 35.0
# month: 36.0
# month: 37.0
# month: 38.0
# month: 39.0
# month: 40.0
# month: 41.0
# month: 42.0
# month: 43.0
# month: 44.0
# month: 45.0
# month: 46.0
# month: 47.0
# month: 48.0
# month: 49.0
# month: 50.0
# month: 51.0
# month: 52.0
# month: 53.0
# month: 54.0
# month: 55.0
# month: 56.0
# month: 57.0
# month: 58.0
# month: 59.0
# month: 60.0
# month: 61.0
# month: 62.0
# month: 63.0
# month: 64.0
# market:2.0
# month: 7.0
# month: 8.0
# month: 9.0
# month: 10.0
# month: 11.0
# month: 12.0
# month: 13.0
# month: 14.0
# month: 15.0
# month: 16.0
# month: 17.0
# month: 18.0
# month: 19.0
# month: 20.0
# month: 21.0
# month: 22.0
# month: 23.0
# month: 24.0
# month: 25.0
# month: 26.0
# month: 27.0
# month: 28.0
# month: 29.0
# month: 30.0
# month: 31.0
#        market  year_month_count  installer_id  \
# 10363    -1.0              64.0         21350
# 10364    -1.0              64.0         21862
# 10365    -1.0              64.0         22375
# 10366    -1.0              64.0         22773
# 10367    -1.0              64.0         21118
#
#                                         reviewidlist_mkt  \
# 10363  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10364  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10365  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10366  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10367  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
#
#                                        reviewidlist_self  \
# 10363  [342, 343, 344, 345, 346, 347, 348, 349, 350, ...
# 10364               [1234, 1235, 1239, 1241, 1259, 2223]
# 10365                                       [2082, 2959]
# 10366                           [2915, 2921, 2926, 3001]
# 10367                               [200, 202, 210, 329]
#
#                                      reviewidlist_others
# 10363  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10364  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10365  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10366  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10367  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...

# %% [markdown]
# ## Output: review_inventory : 2_pipeline/reviewsid_mkt_month_individual_inventory_jan17_2020.csv

# %%
reviewsid_mkt_month_individual_inventory.to_csv('../2_pipeline/reviewsid_mkt_month_individual_inventory_jan17_2020.csv')

# %% [markdown]
# # Part 2 Find the cosine distance based entropy
#
# Use the inventory dataframe produced in part 1

# %%
import pandas as pd
inventory=pd.read_csv('../2_pipeline/reviewsid_mkt_month_individual_inventory_jan17_2020.csv')

# %% [markdown]
# ## Input: read the distance file from folder

# %%
distances_pairs=pd.read_csv('../3_output/ALL_BERT_distances_pairwise_dec30.csv')
distances_pairs.describe()
# Out:
#          Unnamed: 0  Unnamed: 0.1  vec_review_id_1  vec_review_id_2  \
# count  5.700000e+06  5.700000e+06     5.700000e+06     5.700000e+06
# mean   4.999950e+04  4.999950e+04     1.121237e+03     2.259326e+03
# std    2.886752e+04  2.886752e+04     7.856149e+02     7.984089e+02
# min    0.000000e+00  0.000000e+00     1.000000e+00     2.000000e+00
# 25%    2.499975e+04  2.499975e+04     4.540000e+02     1.694000e+03
# 50%    4.999950e+04  4.999950e+04     9.890000e+02     2.396000e+03
# 75%    7.499925e+04  7.499925e+04     1.683000e+03     2.934000e+03
# max    9.999900e+04  9.999900e+04     3.134000e+03     3.396000e+03
#
#        cosine_distance
# count     5.700000e+06
# mean      1.532048e-01
# std       7.658780e-02
# min      -1.192093e-07
# 25%       9.990977e-02
# 50%       1.349529e-01
# 75%       1.870680e-01
# max       7.962324e-01

# %% [markdown]
# ### define a helper function get_distance that get the distance between pairs

# %%
def get_distances(temp_inv):
    return distances_pairs[distances_pairs.vec_review_id_1.isin(temp_inv)&distances_pairs.vec_review_id_2.isin(temp_inv)].cosine_distance

# %% [markdown]
# ## Input: Read the inventory data from Part 1

# %%
inventory=pd.read_csv('../2_pipeline/reviewsid_mkt_month_individual_inventory_jan17_2020.csv')
inventory.head()
# Out:
#    Unnamed: 0  market  year_month_count  installer_id reviewidlist_mkt  \
# 0           0     0.0              35.0         21283               []
# 1           1     0.0              36.0         21283               []
# 2           2     0.0              37.0         21283               []
# 3           3     0.0              38.0         21283               []
# 4           4     0.0              39.0         21283               []
#
#   reviewidlist_self reviewidlist_others
# 0                []                  []
# 1                []                  []
# 2                []                  []
# 3                []                  []
# 4                []                  []

# %% [markdown]
# Look on inventory. For every row, get the reviewidlist_mkt, if not empty, get the median,

# %% [markdown]
# inventory[['text_d_mkt_min','text_d_mkt_p25','text_d_mkt_p50','text_d_mkt_p75','text_d_mkt_max']]=0

# %%
inventory.tail()
# Out:
#        Unnamed: 0  market  year_month_count  installer_id  \
# 10363       10363    -1.0              64.0         21350
# 10364       10364    -1.0              64.0         21862
# 10365       10365    -1.0              64.0         22375
# 10366       10366    -1.0              64.0         22773
# 10367       10367    -1.0              64.0         21118
#
#                                         reviewidlist_mkt  \
# 10363  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10364  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10365  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10366  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10367  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
#
#                                        reviewidlist_self  \
# 10363  [342, 343, 344, 345, 346, 347, 348, 349, 350, ...
# 10364               [1234, 1235, 1239, 1241, 1259, 2223]
# 10365                                       [2082, 2959]
# 10366                           [2915, 2921, 2926, 3001]
# 10367                               [200, 202, 210, 329]
#
#                                      reviewidlist_others
# 10363  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10364  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10365  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10366  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10367  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...

# %% [markdown]
# for i, row in df.iterrows():
#       ifor_val = something
#       if <condition>:
#         ifor_val = something_else
#       df.at[i,'ifor'] = ifor_val

# %% [markdown]
# ## Make the reduced version so we don't have to encounter too many distances lookups

# %% [markdown]
# ### Reduced mkt level list

# %%
inventory_reduced_mkt=inventory[['reviewidlist_mkt']].drop_duplicates().reset_index(drop=True)

# %%
inventory_reduced_mkt.head()
# Out:
#                                     reviewidlist_mkt
# 0                                                 []
# 1                                         [503, 510]
# 2           [503, 510, 853, 854, 855, 856, 863, 866]
# 3  [503, 510, 853, 854, 855, 856, 863, 866, 955, ...
# 4  [503, 510, 853, 854, 855, 856, 863, 866, 955, ...

# %% [markdown]
# ### Reduced self level list

# %%
inventory_reduced_self = inventory[['reviewidlist_self']].drop_duplicates().reset_index(drop=True)
inventory_reduced_self.tail()
# Out:
#                                       reviewidlist_self
# 1234                     [2854, 2910, 2914, 2954, 3072]
# 1235                                             [3064]
# 1236                            [778, 2837, 3119, 3201]
# 1237  [151, 166, 182, 1111, 1122, 1150, 1157, 1158, ...
# 1238         [2854, 2910, 2914, 2954, 3072, 3266, 3298]

# %% [markdown]
# ### Reduced others level list

# %%
inventory_reduced_others=inventory[['reviewidlist_others']].reset_index(drop=True) 
inventory_reduced_others.tail()
# Out:
#                                      reviewidlist_others
# 10363  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10364  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10365  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10366  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10367  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...

# %%
type(inventory_reduced_others.iloc[10334].reviewidlist_others)
# Out:
# str

# %% [markdown]
# ## Calculate the store the summary stats for every reduced level id lists

# %% [markdown]
# ### Calculate and store the summary stats for the reduced market lists

# %%
inventory_reduced_mkt_list=[]
for index, row in inventory_reduced_mkt.iterrows():
    if len(row.reviewidlist_mkt)>2:
        temp=[int(i) for i in row.reviewidlist_mkt.strip('[').strip(']').split(',')]
        if len(temp)>1:
            temp_distances=get_distances(temp)
            stats=temp_distances.describe(percentiles=[0.25,0.5,0.75 ]) 
            #print(stats)
            inventory_reduced_mkt_list.append([index,stats[1],stats[2],stats[3],stats[4],stats[5],stats[6],stats[7]])
            if index%20==0:
                print('we processed {} rows for mkt level'.format(index))
# Out:
# we processed 20 rows for mkt level
# we processed 40 rows for mkt level
# we processed 60 rows for mkt level
# we processed 80 rows for mkt level
# we processed 100 rows for mkt level
# we processed 120 rows for mkt level
# we processed 140 rows for mkt level
# we processed 160 rows for mkt level
# we processed 180 rows for mkt level
# we processed 200 rows for mkt level
# we processed 220 rows for mkt level
# we processed 240 rows for mkt level
# we processed 260 rows for mkt level
# we processed 280 rows for mkt level
# we processed 300 rows for mkt level
# we processed 320 rows for mkt level
# we processed 340 rows for mkt level
# we processed 360 rows for mkt level
# we processed 380 rows for mkt level
# we processed 400 rows for mkt level
# we processed 420 rows for mkt level
# we processed 440 rows for mkt level
# we processed 460 rows for mkt level
# we processed 500 rows for mkt level
# we processed 520 rows for mkt level
# we processed 540 rows for mkt level

# %%
inventory_reduced_mkt_list[1]
# Out:
# [2,
#  0.13148378900119237,
#  0.05357383618628571,
#  0.06895774602890015,
#  0.09243164956569673,
#  0.11075007915496826,
#  0.14962449669837952,
#  0.24646145105361936]

# %%
stats
# Out:
# count    11600.000000
# mean         0.157125
# std          0.085060
# min          0.000000
# 25%          0.100182
# 50%          0.131768
# 75%          0.185321
# max          0.596568
# Name: cosine_distance, dtype: float64

# %% [markdown]
# ## Output: text dispersion for market level

# %%
col_name=['index','text_d_mkt_mean','text_d_mkt_std','text_d_mkt_min','text_d_mkt_p25','text_d_mkt_p50','text_d_mkt_p75','text_d_mkt_max']
inventory_reduced_mkt_df=pd.DataFrame(data=inventory_reduced_mkt_list,columns=col_name)
inventory_reduced_mkt_df.to_csv('../2_pipeline/inventory_reduced_mkt_sumstats_jan18_2020.csv')

# %% [markdown]
# ### Calculate and store the important stats for the reduced self lists

# %%
inventory_reduced_self_list=[]
for index, row in inventory_reduced_self.iterrows():
    if len(row.reviewidlist_self)>2:
        temp=[int(i) for i in row.reviewidlist_self.strip('[').strip(']').split(',')]
        if len(temp)>1:
            temp_distances=get_distances(temp)
            stats=temp_distances.describe(percentiles=[0.25,0.5,0.75 ]) 
            inventory_reduced_self_list.append([index,stats[1],stats[2],stats[3],stats[4],stats[5],stats[6],stats[7]])
            if index%100==0:
                print('we processed {} rows for self level'.format(index))
# Out:
# we processed 100 rows for self level
# we processed 200 rows for self level
# we processed 300 rows for self level
# we processed 400 rows for self level
# we processed 500 rows for self level
# we processed 600 rows for self level
# we processed 900 rows for self level
# we processed 1000 rows for self level
# we processed 1100 rows for self level
# we processed 1200 rows for self level

# %% [markdown]
# ## Output: text dispersion for Installer level Own Dispersion

# %%
col_name=['index','text_d_self_mean','text_d_self_std','text_d_self_min','text_d_self_p25','text_d_self_p50','text_d_self_p75','text_d_self_max']
inventory_reduced_self_df=pd.DataFrame(data=inventory_reduced_self_list,columns=col_name)
inventory_reduced_self_df.to_csv('../2_pipeline/inventory_reduced_self_sumstats_jan18_2020.csv')

# %%
inventory_reduced_self_df.head()
# Out:
#    index  text_d_self_mean  text_d_self_std  text_d_self_min  text_d_self_p25  \
# 0      1          0.232544              NaN         0.232544         0.232544
# 1      2          0.104398         0.024051         0.068958         0.088068
# 2      3          0.124960         0.045977         0.055537         0.091352
# 3      4          0.188121         0.056137         0.125027         0.165909
# 4      5          0.163721         0.062319         0.098760         0.106348
#
#    text_d_self_p50  text_d_self_p75  text_d_self_max
# 0         0.232544         0.232544         0.232544
# 1         0.099304         0.120322         0.149490
# 2         0.111885         0.149483         0.211835
# 3         0.206791         0.219667         0.232544
# 4         0.165909         0.216008         0.232544

# %% [markdown]
# ### Calculate and store the important stats for the reduced other lists

# %%
inventory_reduced_others_list=[]                
for index, row in inventory_reduced_others.iterrows():
    if len(row.reviewidlist_others)>2:
        temp=[int(i) for i in row.reviewidlist_others.strip('[').strip(']').split(',')]
        #print(temp)
        if len(temp)>1:
            temp_distances=get_distances(temp) 
            stats=temp_distances.describe(percentiles=[0.25,0.5,0.75 ]) 
            inventory_reduced_others_list.append([index,stats[1],stats[2],stats[3],stats[4],stats[5],stats[6],stats[7]])
            if index%100==0:
                print('we processed {} rows for other level'.format(index))
# Out:
# we processed 300 rows for other level
# we processed 500 rows for other level
# we processed 600 rows for other level
# we processed 700 rows for other level
# we processed 800 rows for other level
# we processed 900 rows for other level
# we processed 1000 rows for other level
# we processed 1100 rows for other level
# we processed 1200 rows for other level
# we processed 1400 rows for other level
# we processed 1500 rows for other level
# we processed 1600 rows for other level
# we processed 1700 rows for other level
# we processed 1800 rows for other level
# we processed 1900 rows for other level
# we processed 2000 rows for other level
# we processed 2100 rows for other level
# we processed 2200 rows for other level
# we processed 2300 rows for other level
# we processed 2400 rows for other level
# we processed 2500 rows for other level
# we processed 2600 rows for other level
# we processed 2700 rows for other level
# we processed 2800 rows for other level
# we processed 3100 rows for other level
# we processed 3200 rows for other level
# we processed 3600 rows for other level
# we processed 4100 rows for other level
# we processed 4200 rows for other level
# we processed 4300 rows for other level
# we processed 4400 rows for other level
# we processed 4500 rows for other level
# we processed 4600 rows for other level
# we processed 4700 rows for other level
# we processed 4800 rows for other level
# we processed 4900 rows for other level
# we processed 5000 rows for other level
# we processed 5100 rows for other level
# we processed 5200 rows for other level
# we processed 5300 rows for other level
# we processed 5400 rows for other level
# we processed 5500 rows for other level
# we processed 5600 rows for other level
# we processed 5700 rows for other level
# we processed 5800 rows for other level
# we processed 5900 rows for other level
# we processed 6200 rows for other level
# we processed 6400 rows for other level
# we processed 6500 rows for other level
# we processed 6600 rows for other level
# we processed 6700 rows for other level
# we processed 6900 rows for other level
# we processed 7000 rows for other level
# we processed 7100 rows for other level
# we processed 7200 rows for other level
# we processed 7300 rows for other level
# we processed 7400 rows for other level
# we processed 7500 rows for other level
# we processed 7600 rows for other level
# we processed 7700 rows for other level
# we processed 8000 rows for other level
# we processed 8100 rows for other level
# we processed 8200 rows for other level
# we processed 8300 rows for other level
# we processed 8400 rows for other level
# we processed 8500 rows for other level
# we processed 8600 rows for other level
# we processed 8700 rows for other level
# we processed 8800 rows for other level
# we processed 8900 rows for other level
# we processed 9000 rows for other level
# we processed 9100 rows for other level
# we processed 9200 rows for other level
# we processed 9300 rows for other level
# we processed 9400 rows for other level
# we processed 9500 rows for other level
# we processed 9600 rows for other level
# we processed 9800 rows for other level
# we processed 9900 rows for other level
# we processed 10000 rows for other level
# we processed 10100 rows for other level
# we processed 10200 rows for other level
# we processed 10300 rows for other level

# %% [markdown]
# ## Output: text dispersion for installer level others dispersion

# %%
col_name=['index','text_d_others_mean','text_d_others_std','text_d_others_min','text_d_others_p25','text_d_others_p50','text_d_others_p75','text_d_others_max']
inventory_reduced_others_df=pd.DataFrame(data=inventory_reduced_others_list,columns=col_name)
inventory_reduced_others_df.to_csv('../2_pipeline/inventory_reduced_others_sumstats_jan18_2020.csv')

# %%
inventory_reduced_others_df.tail()
# Out:
#       index  text_d_others_mean  text_d_others_std  text_d_others_min  \
# 8734  10363            0.162572           0.087613                0.0
# 8735  10364            0.159029           0.086130                0.0
# 8736  10365            0.157757           0.085470                0.0
# 8737  10366            0.156887           0.085166                0.0
# 8738  10367            0.155964           0.086166                0.0
#
#       text_d_others_p25  text_d_others_p50  text_d_others_p75  \
# 8734           0.102881           0.137298           0.195393
# 8735           0.100628           0.133164           0.189239
# 8736           0.100275           0.132494           0.186630
# 8737           0.100340           0.131543           0.183596
# 8738           0.098928           0.128723           0.184136
#
#       text_d_others_max
# 8734           0.596568
# 8735           0.596568
# 8736           0.596568
# 8737           0.596568
# 8738           0.596568

# %% [markdown]
# # Part 3 merge the produced summary stats to inventory data

# %% [markdown]
# ## first make sure the reduced version has the summary stats by merging them back

# %%
inventory.head()
# Out:
#    Unnamed: 0  market  year_month_count  installer_id reviewidlist_mkt  \
# 0           0     0.0              35.0         21283               []
# 1           1     0.0              36.0         21283               []
# 2           2     0.0              37.0         21283               []
# 3           3     0.0              38.0         21283               []
# 4           4     0.0              39.0         21283               []
#
#   reviewidlist_self reviewidlist_others
# 0                []                  []
# 1                []                  []
# 2                []                  []
# 3                []                  []
# 4                []                  []

# %% [markdown]
# ### ent of others

# %%
inventory_reduced_others.tail()
# Out:
#                                      reviewidlist_others
# 10363  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10364  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10365  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10366  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10367  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...

# %%
inventory_reduced_others['index']=inventory_reduced_others.index

# %%
inventory_reduced_others_df.tail()
# Out:
#       index  text_d_others_mean  text_d_others_std  text_d_others_min  \
# 8734  10363            0.162572           0.087613                0.0
# 8735  10364            0.159029           0.086130                0.0
# 8736  10365            0.157757           0.085470                0.0
# 8737  10366            0.156887           0.085166                0.0
# 8738  10367            0.155964           0.086166                0.0
#
#       text_d_others_p25  text_d_others_p50  text_d_others_p75  \
# 8734           0.102881           0.137298           0.195393
# 8735           0.100628           0.133164           0.189239
# 8736           0.100275           0.132494           0.186630
# 8737           0.100340           0.131543           0.183596
# 8738           0.098928           0.128723           0.184136
#
#       text_d_others_max
# 8734           0.596568
# 8735           0.596568
# 8736           0.596568
# 8737           0.596568
# 8738           0.596568

# %%
inventory_reduced_others_merged=pd.merge(left=inventory_reduced_others,right=inventory_reduced_others_df,on='index',how='left')

# %%
inventory_reduced_others_merged.tail(5)
# Out:
#                                      reviewidlist_others  index  \
# 10363  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...  10363
# 10364  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...  10364
# 10365  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...  10365
# 10366  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...  10366
# 10367  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...  10367
#
#        text_d_others_mean  text_d_others_std  text_d_others_min  \
# 10363            0.162572           0.087613                0.0
# 10364            0.159029           0.086130                0.0
# 10365            0.157757           0.085470                0.0
# 10366            0.156887           0.085166                0.0
# 10367            0.155964           0.086166                0.0
#
#        text_d_others_p25  text_d_others_p50  text_d_others_p75  \
# 10363           0.102881           0.137298           0.195393
# 10364           0.100628           0.133164           0.189239
# 10365           0.100275           0.132494           0.186630
# 10366           0.100340           0.131543           0.183596
# 10367           0.098928           0.128723           0.184136
#
#        text_d_others_max
# 10363           0.596568
# 10364           0.596568
# 10365           0.596568
# 10366           0.596568
# 10367           0.596568

# %%
type(inventory_reduced_others_merged.iloc[10334].reviewidlist_others)
# Out:
# str

# %% [markdown]
# ### ent of self

# %%
inventory_reduced_self['index']=inventory_reduced_self.index

# %%
inventory_reduced_self.head(15)
# Out:
#                                     reviewidlist_self  index
# 0                                                  []      0
# 1                                          [503, 510]      1
# 2                      [853, 854, 855, 856, 863, 866]      2
# 3            [853, 854, 855, 856, 863, 866, 955, 960]      3
# 4                                    [503, 510, 1538]      4
# 5                              [503, 510, 1538, 2760]      5
# 6                                               [250]      6
# 7                                     [250, 277, 288]      7
# 8                           [250, 277, 288, 531, 535]      8
# 9                                     [803, 806, 808]      9
# 10                    [250, 277, 288, 531, 535, 1125]     10
# 11  [803, 806, 808, 1162, 1163, 1164, 1165, 1166, ...     11
# 12                                             [1291]     12
# 13  [803, 806, 808, 1162, 1163, 1164, 1165, 1166, ...     13
# 14                     [2036, 2037, 2038, 2040, 2060]     14

# %%
inventory_reduced_self_df.head()
# Out:
#    index  text_d_self_mean  text_d_self_std  text_d_self_min  text_d_self_p25  \
# 0      1          0.232544              NaN         0.232544         0.232544
# 1      2          0.104398         0.024051         0.068958         0.088068
# 2      3          0.124960         0.045977         0.055537         0.091352
# 3      4          0.188121         0.056137         0.125027         0.165909
# 4      5          0.163721         0.062319         0.098760         0.106348
#
#    text_d_self_p50  text_d_self_p75  text_d_self_max
# 0         0.232544         0.232544         0.232544
# 1         0.099304         0.120322         0.149490
# 2         0.111885         0.149483         0.211835
# 3         0.206791         0.219667         0.232544
# 4         0.165909         0.216008         0.232544

# %%
inventory_reduced_self_merged=pd.merge(left=inventory_reduced_self,right=inventory_reduced_self_df,on='index',how='left')

# %%
inventory_reduced_self_merged.head()
# Out:
#                           reviewidlist_self  index  text_d_self_mean  \
# 0                                        []      0               NaN
# 1                                [503, 510]      1          0.232544
# 2            [853, 854, 855, 856, 863, 866]      2          0.104398
# 3  [853, 854, 855, 856, 863, 866, 955, 960]      3          0.124960
# 4                          [503, 510, 1538]      4          0.188121
#
#    text_d_self_std  text_d_self_min  text_d_self_p25  text_d_self_p50  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN         0.232544         0.232544         0.232544
# 2         0.024051         0.068958         0.088068         0.099304
# 3         0.045977         0.055537         0.091352         0.111885
# 4         0.056137         0.125027         0.165909         0.206791
#
#    text_d_self_p75  text_d_self_max
# 0              NaN              NaN
# 1         0.232544         0.232544
# 2         0.120322         0.149490
# 3         0.149483         0.211835
# 4         0.219667         0.232544

# %% [markdown]
# ### ent of market

# %%
inventory_reduced_mkt['index']=inventory_reduced_mkt.index

# %%
inventory_reduced_mkt.head()
# Out:
#                                     reviewidlist_mkt  index
# 0                                                 []      0
# 1                                         [503, 510]      1
# 2           [503, 510, 853, 854, 855, 856, 863, 866]      2
# 3  [503, 510, 853, 854, 855, 856, 863, 866, 955, ...      3
# 4  [503, 510, 853, 854, 855, 856, 863, 866, 955, ...      4

# %%
inventory_reduced_mkt_df.head()
# Out:
#    index  text_d_mkt_mean  text_d_mkt_std  text_d_mkt_min  text_d_mkt_p25  \
# 0      1         0.232544             NaN        0.232544        0.232544
# 1      2         0.131484        0.053574        0.068958        0.092432
# 2      3         0.143781        0.060078        0.055537        0.092818
# 3      4         0.141036        0.057699        0.055537        0.093159
# 4      5         0.135878        0.056901        0.055537        0.092755
#
#    text_d_mkt_p50  text_d_mkt_p75  text_d_mkt_max
# 0        0.232544        0.232544        0.232544
# 1        0.110750        0.149624        0.246461
# 2        0.129108        0.197542        0.285040
# 3        0.125027        0.195216        0.285040
# 4        0.116766        0.186694        0.285040

# %%
inventory_reduced_mkt_merged=pd.merge(left=inventory_reduced_mkt,right=inventory_reduced_mkt_df,on='index',how='left')

# %%
inventory_reduced_mkt_merged.head()
# Out:
#                                     reviewidlist_mkt  index  text_d_mkt_mean  \
# 0                                                 []      0              NaN
# 1                                         [503, 510]      1         0.232544
# 2           [503, 510, 853, 854, 855, 856, 863, 866]      2         0.131484
# 3  [503, 510, 853, 854, 855, 856, 863, 866, 955, ...      3         0.143781
# 4  [503, 510, 853, 854, 855, 856, 863, 866, 955, ...      4         0.141036
#
#    text_d_mkt_std  text_d_mkt_min  text_d_mkt_p25  text_d_mkt_p50  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN        0.232544        0.232544        0.232544
# 2        0.053574        0.068958        0.092432        0.110750
# 3        0.060078        0.055537        0.092818        0.129108
# 4        0.057699        0.055537        0.093159        0.125027
#
#    text_d_mkt_p75  text_d_mkt_max
# 0             NaN             NaN
# 1        0.232544        0.232544
# 2        0.149624        0.246461
# 3        0.197542        0.285040
# 4        0.195216        0.285040

# %% [markdown]
# ## final merging?

# %%
inventory.head()
# Out:
#    Unnamed: 0  market  year_month_count  installer_id reviewidlist_mkt  \
# 0           0     0.0              35.0         21283               []
# 1           1     0.0              36.0         21283               []
# 2           2     0.0              37.0         21283               []
# 3           3     0.0              38.0         21283               []
# 4           4     0.0              39.0         21283               []
#
#   reviewidlist_self reviewidlist_others
# 0                []                  []
# 1                []                  []
# 2                []                  []
# 3                []                  []
# 4                []                  []

# %%
inventory.describe()
# Out:
#         Unnamed: 0        market  year_month_count  installer_id
# count  10368.00000  10368.000000      10368.000000  10368.000000
# mean    5183.50000     17.804688         45.799479  18044.925637
# std     2993.12813     13.551211         14.398838   6707.334838
# min        0.00000     -1.000000          1.000000    108.000000
# 25%     2591.75000      4.000000         37.000000  20131.000000
# 50%     5183.50000     17.000000         49.000000  20663.000000
# 75%     7775.25000     33.000000         57.000000  21389.000000
# max    10367.00000     36.000000         64.000000  23027.000000

# %% [markdown]
# ### 1. Merge on mkt level ents measures

# %%
inventory_reduced_mkt_merged.head()
# Out:
#                                     reviewidlist_mkt  index  text_d_mkt_mean  \
# 0                                                 []      0              NaN
# 1                                         [503, 510]      1         0.232544
# 2           [503, 510, 853, 854, 855, 856, 863, 866]      2         0.131484
# 3  [503, 510, 853, 854, 855, 856, 863, 866, 955, ...      3         0.143781
# 4  [503, 510, 853, 854, 855, 856, 863, 866, 955, ...      4         0.141036
#
#    text_d_mkt_std  text_d_mkt_min  text_d_mkt_p25  text_d_mkt_p50  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN        0.232544        0.232544        0.232544
# 2        0.053574        0.068958        0.092432        0.110750
# 3        0.060078        0.055537        0.092818        0.129108
# 4        0.057699        0.055537        0.093159        0.125027
#
#    text_d_mkt_p75  text_d_mkt_max
# 0             NaN             NaN
# 1        0.232544        0.232544
# 2        0.149624        0.246461
# 3        0.197542        0.285040
# 4        0.195216        0.285040

# %%
inventory_reduced_mkt_merged=inventory_reduced_mkt_merged.drop(['index'],axis=1).drop_duplicates()

# %%
final_text_ent=pd.merge(left=inventory,right=inventory_reduced_mkt_merged,on='reviewidlist_mkt',how='left')

# %%
final_text_ent.describe()
# Out:
#         Unnamed: 0        market  year_month_count  installer_id  \
# count  10368.00000  10368.000000      10368.000000  10368.000000
# mean    5183.50000     17.804688         45.799479  18044.925637
# std     2993.12813     13.551211         14.398838   6707.334838
# min        0.00000     -1.000000          1.000000    108.000000
# 25%     2591.75000      4.000000         37.000000  20131.000000
# 50%     5183.50000     17.000000         49.000000  20663.000000
# 75%     7775.25000     33.000000         57.000000  21389.000000
# max    10367.00000     36.000000         64.000000  23027.000000
#
#        text_d_mkt_mean  text_d_mkt_std  text_d_mkt_min  text_d_mkt_p25  \
# count      9057.000000     8679.000000    9.057000e+03     9057.000000
# mean          0.137543        0.061768    3.520904e-02        0.096652
# std           0.023551        0.016654    3.656955e-02        0.023670
# min           0.054564        0.005524   -1.192093e-07        0.054564
# 25%           0.131075        0.055473    0.000000e+00        0.086404
# 50%           0.135117        0.064879    3.152883e-02        0.092818
# 75%           0.143472        0.071107    4.966545e-02        0.098796
# max           0.365879        0.151968    3.658786e-01        0.365879
#
#        text_d_mkt_p50  text_d_mkt_p75  text_d_mkt_max
# count     9057.000000     9057.000000     9057.000000
# mean         0.124838        0.165272        0.410440
# std          0.025438        0.031621        0.159751
# min          0.054564        0.054564        0.054564
# 25%          0.115659        0.154873        0.298640
# 50%          0.120884        0.162674        0.420460
# 75%          0.127784        0.176718        0.526690
# max          0.365879        0.369418        0.756485

# %% [markdown]
# ### 2. Merge on self level ents measure

# %%
inventory_reduced_self_merged.head()
# Out:
#                           reviewidlist_self  index  text_d_self_mean  \
# 0                                        []      0               NaN
# 1                                [503, 510]      1          0.232544
# 2            [853, 854, 855, 856, 863, 866]      2          0.104398
# 3  [853, 854, 855, 856, 863, 866, 955, 960]      3          0.124960
# 4                          [503, 510, 1538]      4          0.188121
#
#    text_d_self_std  text_d_self_min  text_d_self_p25  text_d_self_p50  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN         0.232544         0.232544         0.232544
# 2         0.024051         0.068958         0.088068         0.099304
# 3         0.045977         0.055537         0.091352         0.111885
# 4         0.056137         0.125027         0.165909         0.206791
#
#    text_d_self_p75  text_d_self_max
# 0              NaN              NaN
# 1         0.232544         0.232544
# 2         0.120322         0.149490
# 3         0.149483         0.211835
# 4         0.219667         0.232544

# %%
inventory_reduced_self_merged=inventory_reduced_self_merged.drop(['index'],axis=1).drop_duplicates()

# %%
final_text_ent=pd.merge(left=final_text_ent,right=inventory_reduced_self_merged,on='reviewidlist_self',how='left')

# %%
final_text_ent.tail()
# Out:
#        Unnamed: 0  market  year_month_count  installer_id  \
# 10363       10363    -1.0              64.0         21350
# 10364       10364    -1.0              64.0         21862
# 10365       10365    -1.0              64.0         22375
# 10366       10366    -1.0              64.0         22773
# 10367       10367    -1.0              64.0         21118
#
#                                         reviewidlist_mkt  \
# 10363  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10364  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10365  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10366  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10367  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
#
#                                        reviewidlist_self  \
# 10363  [342, 343, 344, 345, 346, 347, 348, 349, 350, ...
# 10364               [1234, 1235, 1239, 1241, 1259, 2223]
# 10365                                       [2082, 2959]
# 10366                           [2915, 2921, 2926, 3001]
# 10367                               [200, 202, 210, 329]
#
#                                      reviewidlist_others  text_d_mkt_mean  \
# 10363  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...         0.157125
# 10364  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...         0.157125
# 10365  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...         0.157125
# 10366  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...         0.157125
# 10367  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...         0.157125
#
#        text_d_mkt_std  text_d_mkt_min  ...  text_d_mkt_p50  text_d_mkt_p75  \
# 10363         0.08506             0.0  ...        0.131768        0.185321
# 10364         0.08506             0.0  ...        0.131768        0.185321
# 10365         0.08506             0.0  ...        0.131768        0.185321
# 10366         0.08506             0.0  ...        0.131768        0.185321
# 10367         0.08506             0.0  ...        0.131768        0.185321
#
#        text_d_mkt_max  text_d_self_mean  text_d_self_std  text_d_self_min  \
# 10363        0.596568          0.098136         0.022455         0.048601
# 10364        0.596568          0.106721         0.020954         0.061483
# 10365        0.596568          0.122692              NaN         0.122692
# 10366        0.596568          0.167972         0.074041         0.074705
# 10367        0.596568          0.196974         0.028975         0.160524
#
#        text_d_self_p25  text_d_self_p50  text_d_self_p75  text_d_self_max
# 10363         0.083058         0.095586         0.113595         0.154108
# 10364         0.097076         0.109613         0.120701         0.142920
# 10365         0.122692         0.122692         0.122692         0.122692
# 10366         0.114051         0.171353         0.221196         0.257659
# 10367         0.173285         0.201712         0.216017         0.233300
#
# [5 rows x 21 columns]

# %%
final_text_ent=final_text_ent.drop(['Unnamed: 0'],axis=1)

# %%
final_text_ent.tail()
# Out:
#        market  year_month_count  installer_id  \
# 10363    -1.0              64.0         21350
# 10364    -1.0              64.0         21862
# 10365    -1.0              64.0         22375
# 10366    -1.0              64.0         22773
# 10367    -1.0              64.0         21118
#
#                                         reviewidlist_mkt  \
# 10363  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10364  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10365  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10366  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10367  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
#
#                                        reviewidlist_self  \
# 10363  [342, 343, 344, 345, 346, 347, 348, 349, 350, ...
# 10364               [1234, 1235, 1239, 1241, 1259, 2223]
# 10365                                       [2082, 2959]
# 10366                           [2915, 2921, 2926, 3001]
# 10367                               [200, 202, 210, 329]
#
#                                      reviewidlist_others  text_d_mkt_mean  \
# 10363  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...         0.157125
# 10364  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...         0.157125
# 10365  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...         0.157125
# 10366  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...         0.157125
# 10367  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...         0.157125
#
#        text_d_mkt_std  text_d_mkt_min  text_d_mkt_p25  text_d_mkt_p50  \
# 10363         0.08506             0.0        0.100182        0.131768
# 10364         0.08506             0.0        0.100182        0.131768
# 10365         0.08506             0.0        0.100182        0.131768
# 10366         0.08506             0.0        0.100182        0.131768
# 10367         0.08506             0.0        0.100182        0.131768
#
#        text_d_mkt_p75  text_d_mkt_max  text_d_self_mean  text_d_self_std  \
# 10363        0.185321        0.596568          0.098136         0.022455
# 10364        0.185321        0.596568          0.106721         0.020954
# 10365        0.185321        0.596568          0.122692              NaN
# 10366        0.185321        0.596568          0.167972         0.074041
# 10367        0.185321        0.596568          0.196974         0.028975
#
#        text_d_self_min  text_d_self_p25  text_d_self_p50  text_d_self_p75  \
# 10363         0.048601         0.083058         0.095586         0.113595
# 10364         0.061483         0.097076         0.109613         0.120701
# 10365         0.122692         0.122692         0.122692         0.122692
# 10366         0.074705         0.114051         0.171353         0.221196
# 10367         0.160524         0.173285         0.201712         0.216017
#
#        text_d_self_max
# 10363         0.154108
# 10364         0.142920
# 10365         0.122692
# 10366         0.257659
# 10367         0.233300

# %% [markdown]
# ### 3. Merge on others level ents measure

# %%
type(final_text_ent.iloc[10334].reviewidlist_others)
# Out:
# str

# %%
inventory_reduced_others_merged=inventory_reduced_others_merged.drop(['index'],axis=1).drop_duplicates()

# %%
final_text_ent.describe()
# Out:
#              market  year_month_count  installer_id  text_d_mkt_mean  \
# count  10368.000000      10368.000000  10368.000000      9057.000000
# mean      17.804688         45.799479  18044.925637         0.137543
# std       13.551211         14.398838   6707.334838         0.023551
# min       -1.000000          1.000000    108.000000         0.054564
# 25%        4.000000         37.000000  20131.000000         0.131075
# 50%       17.000000         49.000000  20663.000000         0.135117
# 75%       33.000000         57.000000  21389.000000         0.143472
# max       36.000000         64.000000  23027.000000         0.365879
#
#        text_d_mkt_std  text_d_mkt_min  text_d_mkt_p25  text_d_mkt_p50  \
# count     8679.000000    9.057000e+03     9057.000000     9057.000000
# mean         0.061768    3.520904e-02        0.096652        0.124838
# std          0.016654    3.656955e-02        0.023670        0.025438
# min          0.005524   -1.192093e-07        0.054564        0.054564
# 25%          0.055473    0.000000e+00        0.086404        0.115659
# 50%          0.064879    3.152883e-02        0.092818        0.120884
# 75%          0.071107    4.966545e-02        0.098796        0.127784
# max          0.151968    3.658786e-01        0.365879        0.365879
#
#        text_d_mkt_p75  text_d_mkt_max  text_d_self_mean  text_d_self_std  \
# count     9057.000000     9057.000000       5313.000000      4096.000000
# mean         0.165272        0.410440          0.136149         0.048521
# std          0.031621        0.159751          0.049345         0.031815
# min          0.054564        0.054564          0.000000         0.002974
# 25%          0.154873        0.298640          0.104640         0.027264
# 50%          0.162674        0.420460          0.125779         0.039913
# 75%          0.176718        0.526690          0.158520         0.061030
# max          0.369418        0.756485          0.381214         0.204801
#
#        text_d_self_min  text_d_self_p25  text_d_self_p50  text_d_self_p75  \
# count     5.313000e+03      5313.000000      5313.000000      5313.000000
# mean      8.346311e-02         0.111118         0.133084         0.160149
# std       5.088104e-02         0.045195         0.051664         0.066405
# min      -1.192093e-07         0.000000         0.000000         0.000000
# 25%       5.186743e-02         0.081767         0.100148         0.117574
# 50%       7.166195e-02         0.103619         0.121747         0.144627
# 75%       1.017198e-01         0.127261         0.153204         0.189867
# max       3.812145e-01         0.381214         0.381214         0.430115
#
#        text_d_self_max
# count      5313.000000
# mean          0.204667
# std           0.097369
# min           0.000000
# 25%           0.130816
# 50%           0.185836
# 75%           0.262202
# max           0.604839

# %%
final_text_ent.tail()
# Out:
#        market  year_month_count  installer_id  \
# 10363    -1.0              64.0         21350
# 10364    -1.0              64.0         21862
# 10365    -1.0              64.0         22375
# 10366    -1.0              64.0         22773
# 10367    -1.0              64.0         21118
#
#                                         reviewidlist_mkt  \
# 10363  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10364  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10365  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10366  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10367  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
#
#                                        reviewidlist_self  \
# 10363  [342, 343, 344, 345, 346, 347, 348, 349, 350, ...
# 10364               [1234, 1235, 1239, 1241, 1259, 2223]
# 10365                                       [2082, 2959]
# 10366                           [2915, 2921, 2926, 3001]
# 10367                               [200, 202, 210, 329]
#
#                                      reviewidlist_others  text_d_mkt_mean  \
# 10363  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...         0.157125
# 10364  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...         0.157125
# 10365  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...         0.157125
# 10366  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...         0.157125
# 10367  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...         0.157125
#
#        text_d_mkt_std  text_d_mkt_min  text_d_mkt_p25  text_d_mkt_p50  \
# 10363         0.08506             0.0        0.100182        0.131768
# 10364         0.08506             0.0        0.100182        0.131768
# 10365         0.08506             0.0        0.100182        0.131768
# 10366         0.08506             0.0        0.100182        0.131768
# 10367         0.08506             0.0        0.100182        0.131768
#
#        text_d_mkt_p75  text_d_mkt_max  text_d_self_mean  text_d_self_std  \
# 10363        0.185321        0.596568          0.098136         0.022455
# 10364        0.185321        0.596568          0.106721         0.020954
# 10365        0.185321        0.596568          0.122692              NaN
# 10366        0.185321        0.596568          0.167972         0.074041
# 10367        0.185321        0.596568          0.196974         0.028975
#
#        text_d_self_min  text_d_self_p25  text_d_self_p50  text_d_self_p75  \
# 10363         0.048601         0.083058         0.095586         0.113595
# 10364         0.061483         0.097076         0.109613         0.120701
# 10365         0.122692         0.122692         0.122692         0.122692
# 10366         0.074705         0.114051         0.171353         0.221196
# 10367         0.160524         0.173285         0.201712         0.216017
#
#        text_d_self_max
# 10363         0.154108
# 10364         0.142920
# 10365         0.122692
# 10366         0.257659
# 10367         0.233300

# %%
final_text_ent=pd.merge(left=final_text_ent,right=inventory_reduced_others_merged,on=['reviewidlist_others'],how='left')
final_text_ent.tail()
# Out:
#        market  year_month_count  installer_id  \
# 10363    -1.0              64.0         21350
# 10364    -1.0              64.0         21862
# 10365    -1.0              64.0         22375
# 10366    -1.0              64.0         22773
# 10367    -1.0              64.0         21118
#
#                                         reviewidlist_mkt  \
# 10363  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10364  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10365  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10366  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
# 10367  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...
#
#                                        reviewidlist_self  \
# 10363  [342, 343, 344, 345, 346, 347, 348, 349, 350, ...
# 10364               [1234, 1235, 1239, 1241, 1259, 2223]
# 10365                                       [2082, 2959]
# 10366                           [2915, 2921, 2926, 3001]
# 10367                               [200, 202, 210, 329]
#
#                                      reviewidlist_others  text_d_mkt_mean  \
# 10363  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...         0.157125
# 10364  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...         0.157125
# 10365  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...         0.157125
# 10366  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...         0.157125
# 10367  [23, 55, 67, 69, 76, 80, 82, 88, 89, 90, 92, 1...         0.157125
#
#        text_d_mkt_std  text_d_mkt_min  text_d_mkt_p25  ...  text_d_self_p50  \
# 10363         0.08506             0.0        0.100182  ...         0.095586
# 10364         0.08506             0.0        0.100182  ...         0.109613
# 10365         0.08506             0.0        0.100182  ...         0.122692
# 10366         0.08506             0.0        0.100182  ...         0.171353
# 10367         0.08506             0.0        0.100182  ...         0.201712
#
#        text_d_self_p75  text_d_self_max  text_d_others_mean  \
# 10363         0.113595         0.154108            0.162572
# 10364         0.120701         0.142920            0.159029
# 10365         0.122692         0.122692            0.157757
# 10366         0.221196         0.257659            0.156887
# 10367         0.216017         0.233300            0.155964
#
#        text_d_others_std  text_d_others_min  text_d_others_p25  \
# 10363           0.087613                0.0           0.102881
# 10364           0.086130                0.0           0.100628
# 10365           0.085470                0.0           0.100275
# 10366           0.085166                0.0           0.100340
# 10367           0.086166                0.0           0.098928
#
#        text_d_others_p50  text_d_others_p75  text_d_others_max
# 10363           0.137298           0.195393           0.596568
# 10364           0.133164           0.189239           0.596568
# 10365           0.132494           0.186630           0.596568
# 10366           0.131543           0.183596           0.596568
# 10367           0.128723           0.184136           0.596568
#
# [5 rows x 27 columns]

# %%
final_text_ent.to_csv('final_text_ent_jan18_2020.csv')

# %%
final_text_ent.describe()
# Out:
#              market  year_month_count  installer_id  text_d_mkt_mean  \
# count  10368.000000      10368.000000  10368.000000      9057.000000
# mean      17.804688         45.799479  18044.925637         0.137543
# std       13.551211         14.398838   6707.334838         0.023551
# min       -1.000000          1.000000    108.000000         0.054564
# 25%        4.000000         37.000000  20131.000000         0.131075
# 50%       17.000000         49.000000  20663.000000         0.135117
# 75%       33.000000         57.000000  21389.000000         0.143472
# max       36.000000         64.000000  23027.000000         0.365879
#
#        text_d_mkt_std  text_d_mkt_min  text_d_mkt_p25  text_d_mkt_p50  \
# count     8679.000000    9.057000e+03     9057.000000     9057.000000
# mean         0.061768    3.520904e-02        0.096652        0.124838
# std          0.016654    3.656955e-02        0.023670        0.025438
# min          0.005524   -1.192093e-07        0.054564        0.054564
# 25%          0.055473    0.000000e+00        0.086404        0.115659
# 50%          0.064879    3.152883e-02        0.092818        0.120884
# 75%          0.071107    4.966545e-02        0.098796        0.127784
# max          0.151968    3.658786e-01        0.365879        0.365879
#
#        text_d_mkt_p75  text_d_mkt_max  ...  text_d_self_p50  text_d_self_p75  \
# count     9057.000000     9057.000000  ...      5313.000000      5313.000000
# mean         0.165272        0.410440  ...         0.133084         0.160149
# std          0.031621        0.159751  ...         0.051664         0.066405
# min          0.054564        0.054564  ...         0.000000         0.000000
# 25%          0.154873        0.298640  ...         0.100148         0.117574
# 50%          0.162674        0.420460  ...         0.121747         0.144627
# 75%          0.176718        0.526690  ...         0.153204         0.189867
# max          0.369418        0.756485  ...         0.381214         0.430115
#
#        text_d_self_max  text_d_others_mean  text_d_others_std  \
# count      5313.000000         8739.000000        8375.000000
# mean          0.204667            0.137360           0.061849
# std           0.097369            0.023529           0.016769
# min           0.000000            0.054564           0.003260
# 25%           0.130816            0.130334           0.055468
# 50%           0.185836            0.135117           0.064664
# 75%           0.262202            0.143384           0.071254
# max           0.604839            0.372957           0.159244
#
#        text_d_others_min  text_d_others_p25  text_d_others_p50  \
# count       8.739000e+03        8739.000000        8739.000000
# mean        3.537682e-02           0.096515           0.124777
# std         3.722176e-02           0.023383           0.025637
# min        -1.192093e-07           0.054031           0.054564
# 25%         0.000000e+00           0.086241           0.115349
# 50%         3.070414e-02           0.092501           0.120633
# 75%         4.961014e-02           0.098924           0.128522
# max         3.729565e-01           0.372957           0.372957
#
#        text_d_others_p75  text_d_others_max
# count        8739.000000        8739.000000
# mean            0.164885           0.409735
# std             0.031449           0.160333
# min             0.054564           0.054564
# 25%             0.154134           0.292546
# 50%             0.162342           0.419871
# 75%             0.175471           0.526690
# max             0.372957           0.756485
#
# [8 rows x 24 columns]

# %%
final_text_ent_condensed=final_text_ent.drop(['reviewidlist_mkt','reviewidlist_self','reviewidlist_others'],axis=1)

# %%
final_text_ent_condensed.describe()
# Out:
#              market  year_month_count  installer_id  text_d_mkt_mean  \
# count  10368.000000      10368.000000  10368.000000      9057.000000
# mean      17.804688         45.799479  18044.925637         0.137543
# std       13.551211         14.398838   6707.334838         0.023551
# min       -1.000000          1.000000    108.000000         0.054564
# 25%        4.000000         37.000000  20131.000000         0.131075
# 50%       17.000000         49.000000  20663.000000         0.135117
# 75%       33.000000         57.000000  21389.000000         0.143472
# max       36.000000         64.000000  23027.000000         0.365879
#
#        text_d_mkt_std  text_d_mkt_min  text_d_mkt_p25  text_d_mkt_p50  \
# count     8679.000000    9.057000e+03     9057.000000     9057.000000
# mean         0.061768    3.520904e-02        0.096652        0.124838
# std          0.016654    3.656955e-02        0.023670        0.025438
# min          0.005524   -1.192093e-07        0.054564        0.054564
# 25%          0.055473    0.000000e+00        0.086404        0.115659
# 50%          0.064879    3.152883e-02        0.092818        0.120884
# 75%          0.071107    4.966545e-02        0.098796        0.127784
# max          0.151968    3.658786e-01        0.365879        0.365879
#
#        text_d_mkt_p75  text_d_mkt_max  ...  text_d_self_p50  text_d_self_p75  \
# count     9057.000000     9057.000000  ...      5313.000000      5313.000000
# mean         0.165272        0.410440  ...         0.133084         0.160149
# std          0.031621        0.159751  ...         0.051664         0.066405
# min          0.054564        0.054564  ...         0.000000         0.000000
# 25%          0.154873        0.298640  ...         0.100148         0.117574
# 50%          0.162674        0.420460  ...         0.121747         0.144627
# 75%          0.176718        0.526690  ...         0.153204         0.189867
# max          0.369418        0.756485  ...         0.381214         0.430115
#
#        text_d_self_max  text_d_others_mean  text_d_others_std  \
# count      5313.000000         8739.000000        8375.000000
# mean          0.204667            0.137360           0.061849
# std           0.097369            0.023529           0.016769
# min           0.000000            0.054564           0.003260
# 25%           0.130816            0.130334           0.055468
# 50%           0.185836            0.135117           0.064664
# 75%           0.262202            0.143384           0.071254
# max           0.604839            0.372957           0.159244
#
#        text_d_others_min  text_d_others_p25  text_d_others_p50  \
# count       8.739000e+03        8739.000000        8739.000000
# mean        3.537682e-02           0.096515           0.124777
# std         3.722176e-02           0.023383           0.025637
# min        -1.192093e-07           0.054031           0.054564
# 25%         0.000000e+00           0.086241           0.115349
# 50%         3.070414e-02           0.092501           0.120633
# 75%         4.961014e-02           0.098924           0.128522
# max         3.729565e-01           0.372957           0.372957
#
#        text_d_others_p75  text_d_others_max
# count        8739.000000        8739.000000
# mean            0.164885           0.409735
# std             0.031449           0.160333
# min             0.054564           0.054564
# 25%             0.154134           0.292546
# 50%             0.162342           0.419871
# 75%             0.175471           0.526690
# max             0.372957           0.756485
#
# [8 rows x 24 columns]

# %% [markdown]
# ## Output: the merged text dispersion data

# %%
final_text_ent_condensed.to_csv('..2_pipeline/BERTtext_ent_90_100_2steps.csv')
